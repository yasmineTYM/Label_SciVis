# %%
## append two columns: LabelKeyword, Tag 

import pandas as pd

data = pd.read_csv('vispub.csv')

# %%
total_length = len(data)
temp_k = []
temp_t = []
for i in range(total_length):
    temp_k.append('')
    temp_t.append('todo')
data['LabelKeyword'] = temp_k
data['Tag'] = temp_t

# %%
data.head(3)
# Out:
#     Unnamed: 0  Unnamed: 0.1  \
# 0 0        Vis          1990
# 1 1        Vis          1990
# 2 2        Vis          1990
#
#                                             Conference  \
# 0 0  Interdisciplinary visualization: lessons learn...
# 1 1  Surface representations of two- and three-dime...
# 2 2  FAST: a multi-processed environment for visual...
#
#                            Year  \
# 0 0            10.0000/00000002
# 1 1  10.1109/VISUAL.1990.146359
# 2 2  10.1109/VISUAL.1990.146360
#
#                                                  Title  DOI       Link  \
# 0 0  http://dl.acm.org/citation.cfm?id=949606&CFID=...  457        457
# 1 1       http://dx.doi.org/10.1109/VISUAL.1990.146359    6    13, 460
# 2 2       http://dx.doi.org/10.1109/VISUAL.1990.146360   14  27, 461-2
#
#     FirstPage                                           LastPage  \
# 0 0         M                                                NaN
# 1 1         C  The use of critical point analysis to generate...
# 2 2         C  The authors discuss FAST (flow analysis softwa...
#
#                                              PaperType  ... AuthorNames  \
# 0 0                                       Donna J. Cox  ...         NaN
# 1 1                   James Helman;Lambertus Hesselink  ...         NaN
# 2 2  Gordon V. Bancroft;Fergus Merritt;Todd Plessel...  ...         NaN
#
#     AuthorAffiliation InternalReferences AuthorKeywords  \
# 0 0               NaN                0.0            NaN
# 1 1               NaN               67.0            0.0
# 2 2               NaN               71.0            6.0
#
#      AminerCitationCount_02-2020  XploreCitationCount - 2020-01  PubsCited  \
# 0 0                          NaN                            NaN        NaN
# 1 1                         11.0                             BP        NaN
# 2 2                         20.0                            NaN        NaN
#
#     Award  LabelKeyword   Tag
# 0 0   NaN                todo
# 1 1   NaN                todo
# 2 2   NaN                todo
#
# [3 rows x 22 columns]

# %%
data.to_csv('vispub.csv',index=False)
